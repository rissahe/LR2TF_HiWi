# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("/home/larissa/Documents/LR2TF_HiWi/script_test/TF_results/control/control_specific_markers_wilcoxon_test.csv")

sns.histplot(df["logfoldchanges"])
# Out:
# <Axes: xlabel='logfoldchanges', ylabel='Count'>
